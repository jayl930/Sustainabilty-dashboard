# %%
import requests
import json

def fetch_and_process_persons():
    url = 'https://experts.illinois.edu/ws/api/524/persons'

    # Adjusted fields parameter to include details explicitly
    fields = 'uuid,externalId,name.firstName,name.lastName,staffOrganisationAssociations.organisationalUnit.name.text.value,profileInformations.value.text.value'

    # Headers to request a JSON response
    headers = {'Accept': 'application/json'}

    # Initialize the list to hold all refined person information
    all_refined_info = []

    # Initial parameters for pagination
    params = {
        'apiKey': '5fb8492f-6462-49fd-b3dd-69c896549ff8',
        'size': 500,  # Adjust as per the API's limits and requirements
        'offset': 0,
        'fields': fields
    }

    total_persons = 2971  
    while params['offset'] < total_persons:
        response = requests.get(url, headers=headers, params=params)
        if response.status_code == 200:
            data = response.json()
            items = data.get('items', [])

            for item in items:
                # Construct full name and extract information
                full_name = f"{item.get('name', {}).get('firstName', '')} {item.get('name', {}).get('lastName', '')}".strip()
                organisational_units = [ou.get('organisationalUnit', {}).get('name', {}).get('text', [{}])[0].get('value', 'N/A')
                                        for ou in item.get('staffOrganisationAssociations', [])
                                        if ou.get('organisationalUnit')]

                research_interests = "N/A"
                profile_info = item.get('profileInformations', [])
                if profile_info:
                    research_interests = profile_info[0].get('value', {}).get('text', [{}])[0].get('value', 'N/A')

                person_info = {
                    'uuid': item.get('uuid', 'N/A'),
                    'email': item.get('externalId', 'N/A'),
                    'name': full_name,
                    'organization': organisational_units if organisational_units else ['N/A'],
                    'about': research_interests
                }

                all_refined_info.append(person_info)

            params['offset'] += params['size']
        else:
            print(f"Failed to retrieve data. Status code: {response.status_code}, Response content: {response.text}")
            break

    # Convert and save or print the refined person information
    refined_json = json.dumps(all_refined_info, indent=4)
    filename = 'researchers.json'
    with open(filename, 'w') as f:
        f.write(refined_json)
    print(f"Refined person data saved to {filename}")

# Call the function to start fetching and processing person information
fetch_and_process_persons()
# Out:
# Refined person data saved to researchers.json

# %%
import pandas as pd
import requests
import json

# %%
file_path = 'researchers.json'
with open(file_path, 'r') as file:
    data = json.load(file)

df = pd.DataFrame(data)

df['organization'] = df['organization'].apply(lambda units: list(set(units)))

df.head()
# Out:
#                                    uuid                  email  \
# 0  11b4c73a-d90d-4ef5-85d1-b37da6a64270  abbamont@illinois.edu
# 1  ff337faa-24e5-4cb1-be6b-07285ec7b49a   ahdyson@illinois.edu
# 2  6f5808b8-fe1c-49a9-90b8-0cf4980d371b  agewirth@illinois.edu
# 3  395244cc-d551-417a-b3b5-85b455a2dcc9  aiwillis@illinois.edu
# 4  094081a5-552c-48ab-b076-0c9f316002c5  aleggett@illinois.edu
#
#                       name                                     organization  \
# 0  Peter Michael Abbamonte                [Materials Research Lab, Physics]
# 1          Anne Haas Dyson  [Education Policy, Organization and Leadership]
# 2         Andrew A Gewirth              [Materials Research Lab, Chemistry]
# 3         Arlette I Willis                     [Curriculum and Instruction]
# 4        Anthony J Leggett                                        [Physics]
#
#                                                about
# 0                                                N/A
# 1  <p>Anne Haas Dyson is a former teacher of youn...
# 2  <p><span>Professor Andrew A. Gewirth received ...
# 3                                                N/A
# 4                                                N/A

# %%
name_counts = {}

def update_name(name):
    if name in name_counts:
        name_counts[name] += 1
        return f"{name} {name_counts[name]}"
    else:
        name_counts[name] = 1
        return name

df['name'] = df['name'].apply(update_name)

# %%
df[df['email'] == 'mem12@illinois.edu']
# Out:
# Empty DataFrame
# Columns: [uuid, email, name, organization, about]
# Index: []

# %%
df['organization'] = df['organization'].apply(lambda x: ', '.join(x) if isinstance(x, list) else x)
df['about'] = df['about'].str.replace('<[^>]+>', '', regex=True)

df.head()
# Out:
#                                    uuid                  email  \
# 0  11b4c73a-d90d-4ef5-85d1-b37da6a64270  abbamont@illinois.edu
# 1  ff337faa-24e5-4cb1-be6b-07285ec7b49a   ahdyson@illinois.edu
# 2  6f5808b8-fe1c-49a9-90b8-0cf4980d371b  agewirth@illinois.edu
# 3  395244cc-d551-417a-b3b5-85b455a2dcc9  aiwillis@illinois.edu
# 4  094081a5-552c-48ab-b076-0c9f316002c5  aleggett@illinois.edu
#
#                       name                                   organization  \
# 0  Peter Michael Abbamonte                Materials Research Lab, Physics
# 1          Anne Haas Dyson  Education Policy, Organization and Leadership
# 2         Andrew A Gewirth              Materials Research Lab, Chemistry
# 3         Arlette I Willis                     Curriculum and Instruction
# 4        Anthony J Leggett                                        Physics
#
#                                                about
# 0                                                N/A
# 1  Anne Haas Dyson is a former teacher of young c...
# 2  Professor Andrew A. Gewirth received his A.B. ...
# 3                                                N/A
# 4                                                N/A

# %%
file_path = 'people.tsv'
df.to_csv(file_path, sep='\t', index=False)

# %%
df['articles'] = pd.Series([[] for _ in range(len(df))])

# %%
df
# Out:
#                                       uuid                  email  \
# 0     11b4c73a-d90d-4ef5-85d1-b37da6a64270  abbamont@illinois.edu
# 1     ff337faa-24e5-4cb1-be6b-07285ec7b49a   ahdyson@illinois.edu
# 2     6f5808b8-fe1c-49a9-90b8-0cf4980d371b  agewirth@illinois.edu
# 3     395244cc-d551-417a-b3b5-85b455a2dcc9  aiwillis@illinois.edu
# 4     094081a5-552c-48ab-b076-0c9f316002c5  aleggett@illinois.edu
# ...                                    ...                    ...
# 2966  3d8b467e-e0f3-48aa-b46f-71ebc40af089     hungn@illinois.edu
# 2967  ede16d00-5c54-479a-8f83-402e7806cf77  mkumar41@illinois.edu
# 2968  a262ace2-f4a0-437e-baf5-872fbc5b73a2    rwarne@illinois.edu
# 2969  1b25d1c1-026a-4f76-be51-5d9e3a9d2da1    raovnv@illinois.edu
# 2970  d704a5e4-54bd-44b0-9d3e-23320038f1f8    sofiaz@illinois.edu
#
#                          name                                   organization  \
# 0     Peter Michael Abbamonte                Materials Research Lab, Physics
# 1             Anne Haas Dyson  Education Policy, Organization and Leadership
# 2            Andrew A Gewirth              Materials Research Lab, Chemistry
# 3            Arlette I Willis                     Curriculum and Instruction
# 4           Anthony J Leggett                                        Physics
# ...                       ...                                            ...
# 2966     Tan Thai Hung Nguyen         Earth Science and Environmental Change
# 2967             Manish Kumar                     Applied Research Institute
# 2968      Robin William Warne                     Prairie Research Institute
# 2969              Vimal V Rao             Educational Psychology, Statistics
# 2970          Sofia Zaragocin   Geography and Geographic Information Science
#
#                                                   about articles
# 0                                                   N/A       []
# 1     Anne Haas Dyson is a former teacher of young c...       []
# 2     Professor Andrew A. Gewirth received his A.B. ...       []
# 3                                                   N/A       []
# 4                                                   N/A       []
# ...                                                 ...      ...
# 2966                                                N/A       []
# 2967                                                N/A       []
# 2968                                                N/A       []
# 2969                                                N/A       []
# 2970                                                N/A       []
#
# [2971 rows x 6 columns]

# %%
df = pd.read_csv('dataframe.tsv', sep='\t')

# %%
base_url = 'https://experts.illinois.edu/ws/api/524/persons'

headers = {'Accept': 'application/json'}
api_key = '5fb8492f-6462-49fd-b3dd-69c896549ff8' 


for index, row in df.iterrows():
    if index < 2971:
        continue
        
    person_uuid = row['uuid']
    url = f"{base_url}/{person_uuid}/research-outputs"

    params = {
        'apiKey': api_key,
        'size': 1000,
        'offset': 0,
    }

    response = requests.get(url, headers=headers, params=params)

    if response.status_code == 200:
        data = response.json()
        research_output_uuids = [item['uuid'] for item in data.get('items', [])]
        df.at[index, 'articles'] = research_output_uuids

# %%
file_path = 'final.tsv'
df.to_csv(file_path, sep='\t', index=False)

# %%
df
# Out:
#                                       uuid                  email  \
# 0     11b4c73a-d90d-4ef5-85d1-b37da6a64270  abbamont@illinois.edu
# 1     ff337faa-24e5-4cb1-be6b-07285ec7b49a   ahdyson@illinois.edu
# 2     6f5808b8-fe1c-49a9-90b8-0cf4980d371b  agewirth@illinois.edu
# 3     395244cc-d551-417a-b3b5-85b455a2dcc9  aiwillis@illinois.edu
# 4     094081a5-552c-48ab-b076-0c9f316002c5  aleggett@illinois.edu
# ...                                    ...                    ...
# 2966  3d8b467e-e0f3-48aa-b46f-71ebc40af089     hungn@illinois.edu
# 2967  ede16d00-5c54-479a-8f83-402e7806cf77  mkumar41@illinois.edu
# 2968  a262ace2-f4a0-437e-baf5-872fbc5b73a2    rwarne@illinois.edu
# 2969  1b25d1c1-026a-4f76-be51-5d9e3a9d2da1    raovnv@illinois.edu
# 2970  d704a5e4-54bd-44b0-9d3e-23320038f1f8    sofiaz@illinois.edu
#
#                          name                                   organization  \
# 0     Peter Michael Abbamonte                Materials Research Lab, Physics
# 1             Anne Haas Dyson  Education Policy, Organization and Leadership
# 2            Andrew A Gewirth              Materials Research Lab, Chemistry
# 3            Arlette I Willis                     Curriculum and Instruction
# 4           Anthony J Leggett                                        Physics
# ...                       ...                                            ...
# 2966     Tan Thai Hung Nguyen         Earth Science and Environmental Change
# 2967             Manish Kumar                     Applied Research Institute
# 2968      Robin William Warne                     Prairie Research Institute
# 2969              Vimal V Rao             Educational Psychology, Statistics
# 2970          Sofia Zaragocin   Geography and Geographic Information Science
#
#                                                   about articles
# 0                                                   N/A       []
# 1     Anne Haas Dyson is a former teacher of young c...       []
# 2     Professor Andrew A. Gewirth received his A.B. ...       []
# 3                                                   N/A       []
# 4                                                   N/A       []
# ...                                                 ...      ...
# 2966                                                N/A       []
# 2967                                                N/A       []
# 2968                                                N/A       []
# 2969                                                N/A       []
# 2970                                                N/A       []
#
# [2971 rows x 6 columns]

# %%
def clean_organization_list(org_list_str):
    org_list = ast.literal_eval(org_list_str)
    cleaned_list = list(set(org_list))
    return cleaned_list

people['organization'] = people['organization'].apply(clean_organization_list)

# %%
data = pd.read_csv('final.tsv', sep='\t')

# %%
data.head(100)
# Out:
#                                     uuid                  email  \
# 0   11b4c73a-d90d-4ef5-85d1-b37da6a64270  abbamont@illinois.edu
# 1   ff337faa-24e5-4cb1-be6b-07285ec7b49a   ahdyson@illinois.edu
# 2   6f5808b8-fe1c-49a9-90b8-0cf4980d371b  agewirth@illinois.edu
# 3   395244cc-d551-417a-b3b5-85b455a2dcc9  aiwillis@illinois.edu
# 4   094081a5-552c-48ab-b076-0c9f316002c5  aleggett@illinois.edu
# ..                                   ...                    ...
# 95  c9fee833-b303-4f6b-99fa-5d58d12d5d23     livtd@illinois.edu
# 96  37327e28-57f7-4bbc-90be-5527ff815132     liora@illinois.edu
# 97  683c93b6-abe7-49f1-a1cf-064a35f1230d    luting@illinois.edu
# 98  0fef1d11-2d43-4fc2-8099-d2da9f0a4040  m-nelson@illinois.edu
# 99  6709e750-c661-45df-ac15-64b4aff8e837  mahughes@illinois.edu
#
#                                name  \
# 0           Peter Michael Abbamonte
# 1                   Anne Haas Dyson
# 2                  Andrew A Gewirth
# 3                  Arlette I Willis
# 4                 Anthony J Leggett
# ..                              ...
# 95  Liv Solveig Thorstensson Davila
# 96                    Liora Bresler
# 97                          Ting Lu
# 98                    Mark E Nelson
# 99               Mary-Alayne Hughes
#
#                                          organization  \
# 0                     Materials Research Lab, Physics
# 1       Education Policy, Organization and Leadership
# 2                   Materials Research Lab, Chemistry
# 3                          Curriculum and Instruction
# 4                                             Physics
# ..                                                ...
# 95  European Union Center, Women & Gender in Globa...
# 96                         Curriculum and Instruction
# 97  Bioengineering, National Center for Supercompu...
# 98               Molecular and Integrative Physiology
# 99                                  Special Education
#
#                                                 about articles
# 0                                                 NaN       []
# 1   Anne Haas Dyson is a former teacher of young c...       []
# 2   Professor Andrew A. Gewirth received his A.B. ...       []
# 3                                                 NaN       []
# 4                                                 NaN       []
# ..                                                ...      ...
# 95  My research focusses on languages, literacies ...       []
# 96  Bresler’s interdisciplinary work focuses on th...       []
# 97                                                NaN       []
# 98  Research Topics\nComputational Biology, Neurob...       []
# 99                                                NaN       []
#
# [100 rows x 6 columns]

# %%
df
# Out:
#                                       uuid                  email  \
# 0     11b4c73a-d90d-4ef5-85d1-b37da6a64270  abbamont@illinois.edu
# 1     ff337faa-24e5-4cb1-be6b-07285ec7b49a   ahdyson@illinois.edu
# 2     6f5808b8-fe1c-49a9-90b8-0cf4980d371b  agewirth@illinois.edu
# 3     395244cc-d551-417a-b3b5-85b455a2dcc9  aiwillis@illinois.edu
# 4     094081a5-552c-48ab-b076-0c9f316002c5  aleggett@illinois.edu
# ...                                    ...                    ...
# 2966  3d8b467e-e0f3-48aa-b46f-71ebc40af089     hungn@illinois.edu
# 2967  ede16d00-5c54-479a-8f83-402e7806cf77  mkumar41@illinois.edu
# 2968  a262ace2-f4a0-437e-baf5-872fbc5b73a2    rwarne@illinois.edu
# 2969  1b25d1c1-026a-4f76-be51-5d9e3a9d2da1    raovnv@illinois.edu
# 2970  d704a5e4-54bd-44b0-9d3e-23320038f1f8    sofiaz@illinois.edu
#
#                          name                                   organization  \
# 0     Peter Michael Abbamonte                Materials Research Lab, Physics
# 1             Anne Haas Dyson  Education Policy, Organization and Leadership
# 2            Andrew A Gewirth              Materials Research Lab, Chemistry
# 3            Arlette I Willis                     Curriculum and Instruction
# 4           Anthony J Leggett                                        Physics
# ...                       ...                                            ...
# 2966     Tan Thai Hung Nguyen         Earth Science and Environmental Change
# 2967             Manish Kumar                     Applied Research Institute
# 2968      Robin William Warne                     Prairie Research Institute
# 2969              Vimal V Rao             Educational Psychology, Statistics
# 2970          Sofia Zaragocin   Geography and Geographic Information Science
#
#                                                   about  \
# 0                                                   N/A
# 1     Anne Haas Dyson is a former teacher of young c...
# 2     Professor Andrew A. Gewirth received his A.B. ...
# 3                                                   N/A
# 4                                                   N/A
# ...                                                 ...
# 2966                                                N/A
# 2967                                                N/A
# 2968                                                N/A
# 2969                                                N/A
# 2970                                                N/A
#
#                                                articles
# 0                                                    []
# 1                                                    []
# 2                                                    []
# 3                                                    []
# 4                                                    []
# ...                                                 ...
# 2966  [4e96f7ba-c0a2-4fb3-a674-01de2ea5a337, ec2721f...
# 2967                                                 []
# 2968  [20b8fe9b-cf3a-426b-8624-b4759f3709a7, f5cc349...
# 2969  [9587ce9f-162e-4b01-9c5a-5b99a8aa1618, d36571c...
# 2970  [0deac159-5fa0-4514-a3d7-d7d5b41211f3, 825d4ea...
#
# [2971 rows x 6 columns]
